# %% [markdown]
# ### Supervised Learning Project

# %% [markdown]
# ### Saif Merchant

# %% [markdown]
# # Part 1

# %% [markdown]
# #### 1.1

# %% [markdown]
# ##### a -Read all the 3 CSV files as DataFrame and store them into 3 separate variables

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
normal = pd.read_csv("C:/Users/SAIF MERCHANT/Desktop/Great Learning/Supervised Learning/Project/Part1+-+Normal.csv")
type_h = pd.read_csv("C:/Users/SAIF MERCHANT/Desktop/Great Learning/Supervised Learning/Project/Part1+-+Type_H.csv")
type_s = pd.read_csv("C:/Users/SAIF MERCHANT/Desktop/Great Learning/Supervised Learning/Project/Part1+-+Type_S.csv")

# %% [markdown]
# ##### b -Print Shape and columns of all the 3 DataFrames

# %%
print('Columns :  ',normal.columns)
print(' ')
print('Shape : ',normal.shape)
# Out:
# Columns :   Index(['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree',
#        'Class'],
#       dtype='object')
#
# Shape :  (100, 7)

# %%
print('Columns :  ',type_h.columns)
print(' ')
print('Shape : ',type_h.shape)
# Out:
# Columns :   Index(['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree',
#        'Class'],
#       dtype='object')
#
# Shape :  (60, 7)

# %%
print('Columns :  ',type_s.columns)
print(' ')
print('Shape : ',type_s.shape)
# Out:
# Columns :   Index(['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree',
#        'Class'],
#       dtype='object')
#
# Shape :  (150, 7)

# %% [markdown]
# ##### c -Compare Column names of all the 3 DataFrames and clearly write observations

# %%
normal_1 = normal.columns
type_h_1 = type_h.columns
type_s_1 = type_s.columns

if normal_1.equals(type_h_1) and normal.equals(type_s_1):
    print("All three DataFrames have the same column names.")
else:
    print("Column names differ among the DataFrames.")
# Out:
# Column names differ among the DataFrames.

# %% [markdown]
# The column names in all three DataFrames (normal, type_h, and type_s) appear to be the same.

# %% [markdown]
# ##### d - Print DataTypes of all the 3 DataFrames.

# %%
normal.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
type_h.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
type_s.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %% [markdown]
# ##### e - Observe and share variation in ‘Class’ feature of all the 3 DaraFrames

# %%
print('Dataframe 1 : Normal : ')
print(' ')
print(' ')
print('Categirical Info : ')
print(normal.info())
print(' ')
print(' ')
print('Null / Non - Null Values : ')
print(normal.isnull().sum())
print(' ')
print(' ')
print('Unique Values for Class : ')
print(normal['Class'].unique())
print(' ')
print(' ')
print('Attribute Frequency for Class: ')
print(normal['Class'].value_counts())
# Out:
# Dataframe 1 : Normal :
#
#
# Categirical Info :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  100 non-null    float64
#  1   P_tilt       100 non-null    float64
#  2   L_angle      100 non-null    float64
#  3   S_slope      100 non-null    float64
#  4   P_radius     100 non-null    float64
#  5   S_Degree     100 non-null    float64
#  6   Class        100 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 5.6+ KB
# None
#
#
# Null / Non - Null Values :
# P_incidence    0
# P_tilt         0
# L_angle        0
# S_slope        0
# P_radius       0
# S_Degree       0
# Class          0
# dtype: int64
#
#
# Unique Values for Class :
# ['Normal' 'Nrmal']
#
#
# Attribute Frequency for Class:
# Normal    73
# Nrmal     27
# Name: Class, dtype: int64

# %%
print('Dataframe 2 : Type_H : ')
print(' ')
print(' ')
print('Categirical Info : ')
print(type_h.info())
print(' ')
print(' ')
print('Null / Non - Null Values : ')
print(type_h.isnull().sum())
print(' ')
print(' ')
print('Unique Values for Class : ')
print(type_h['Class'].unique())
print(' ')
print(' ')
print('Attribute Frequency for Class: ')
print(type_h['Class'].value_counts())
# Out:
# Dataframe 2 : Type_H :
#
#
# Categirical Info :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  60 non-null     float64
#  1   P_tilt       60 non-null     float64
#  2   L_angle      60 non-null     float64
#  3   S_slope      60 non-null     float64
#  4   P_radius     60 non-null     float64
#  5   S_Degree     60 non-null     float64
#  6   Class        60 non-null     object
# dtypes: float64(6), object(1)
# memory usage: 3.4+ KB
# None
#
#
# Null / Non - Null Values :
# P_incidence    0
# P_tilt         0
# L_angle        0
# S_slope        0
# P_radius       0
# S_Degree       0
# Class          0
# dtype: int64
#
#
# Unique Values for Class :
# ['Type_H' 'type_h']
#
#
# Attribute Frequency for Class:
# Type_H    37
# type_h    23
# Name: Class, dtype: int64

# %%
print('Dataframe 3 : Type_S : ')
print(' ')
print(' ')
print('Categirical Info : ')
print(type_s.info())
print(' ')
print(' ')
print('Null / Non - Null Values : ')
print(type_s.isnull().sum())
print(' ')
print(' ')
print('Unique Values for Class : ')
print(type_s['Class'].unique())
print(' ')
print(' ')
print('Attribute Frequency for Class: ')
print(type_s['Class'].value_counts())
# Out:
# Dataframe 3 : Type_S :
#
#
# Categirical Info :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  150 non-null    float64
#  1   P_tilt       150 non-null    float64
#  2   L_angle      150 non-null    float64
#  3   S_slope      150 non-null    float64
#  4   P_radius     150 non-null    float64
#  5   S_Degree     150 non-null    float64
#  6   Class        150 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 8.3+ KB
# None
#
#
# Null / Non - Null Values :
# P_incidence    0
# P_tilt         0
# L_angle        0
# S_slope        0
# P_radius       0
# S_Degree       0
# Class          0
# dtype: int64
#
#
# Unique Values for Class :
# ['Type_S' 'tp_s']
#
#
# Attribute Frequency for Class:
# Type_S    133
# tp_s       17
# Name: Class, dtype: int64

# %% [markdown]
# #### 1.2

# %% [markdown]
# ##### a - Unify all the variations in ‘Class’ feature for all the 3 DataFrames

# %%
normal['Class'] = normal['Class'].str.replace('Nrmal', 'Normal')

# %%
normal['Class'].unique()
# Out:
# array(['Normal'], dtype=object)

# %%
type_h['Class'] = type_h['Class'].str.replace('type_h', 'Type_H')

# %%
type_h['Class'].unique()
# Out:
# array(['Type_H'], dtype=object)

# %%
type_s['Class'] = type_s['Class'].str.replace('tp_s', 'Type_S')

# %%
type_s['Class'].unique()
# Out:
# array(['Type_S'], dtype=object)

# %% [markdown]
# ##### b - Combine all the 3 DataFrames to form a single DataFrame

# %%
new_data = pd.merge(normal,type_h,how = 'outer')
new_data = pd.merge(new_data,type_s,how = 'outer')

# %%
new_data
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius    S_Degree  \
# 0      38.505273  16.964297  35.112814  21.540976  127.632875    7.986683
# 1      54.920858  18.968430  51.601455  35.952428  125.846646    2.001642
# 2      44.362490   8.945435  46.902096  35.417055  129.220682    4.994195
# 3      48.318931  17.452121  48.000000  30.866809  128.980308   -0.910941
# 4      45.701789  10.659859  42.577846  35.041929  130.178314   -3.388910
# ..           ...        ...        ...        ...         ...         ...
# 305    80.111572  33.942432  85.101608  46.169139  125.593624  100.292107
# 306    95.480229  46.550053  59.000000  48.930176   96.683903   77.283072
# 307    74.094731  18.823727  76.032156  55.271004  128.405731   73.388216
# 308    87.679087  20.365613  93.822416  67.313473  120.944829   76.730629
# 309    48.259920  16.417462  36.329137  31.842457   94.882336   28.343799
#
#       Class
# 0    Normal
# 1    Normal
# 2    Normal
# 3    Normal
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Type_S    150
# Normal    100
# Type_H     60
# Name: Class, dtype: int64

# %% [markdown]
# ##### c - Print 5 random samples of this DataFrame

# %%
random_samples = new_data.sample(n=5)

# %%
random_samples
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius    S_Degree  \
# 97     61.446597  22.694968  46.170347  38.751628  125.670725   -2.707880
# 102    68.832021  22.218482  50.092194  46.613539  105.985135   -3.530317
# 224    74.717228  14.321679  32.500000  60.395549  107.182218   37.017080
# 302    76.314028  41.933683  93.284863  34.380345  132.267286  101.218783
# 181    74.005541  21.122402  57.379502  52.883139  120.205963   74.555166
#
#       Class
# 97   Normal
# 102  Type_H
# 224  Type_S
# 302  Type_S
# 181  Type_S

# %% [markdown]
# ##### d - Print Feature-wise percentage of Null values

# %%
pd.DataFrame({'Count' : new_data.isnull().sum()[new_data.isnull().sum() > 0],
             'Percentage' : (new_data.isnull().sum()[new_data.isnull().sum() > 0]/new_data.shape[0])*100})
# Out:
# Empty DataFrame
# Columns: [Count, Percentage]
# Index: []

# %% [markdown]
# #### or

# %%
print(new_data.isnull().mean() * 100)
# Out:
# P_incidence    0.0
# P_tilt         0.0
# L_angle        0.0
# S_slope        0.0
# P_radius       0.0
# S_Degree       0.0
# Class          0.0
# dtype: float64

# %% [markdown]
# ###### As there are no null values, the outputs for both are empty

# %% [markdown]
# ##### e - Check 5-point summary of the new DataFrame

# %%
new_data.describe().T
# Out:
#              count        mean        std        min         25%         50%  \
# P_incidence  310.0   60.496653  17.236520  26.147921   46.430294   58.691038
# P_tilt       310.0   17.542822  10.008330  -6.554948   10.667069   16.357689
# L_angle      310.0   51.930930  18.554064  14.000000   37.000000   49.562398
# S_slope      310.0   42.953831  13.423102  13.366931   33.347122   42.404912
# P_radius     310.0  117.920655  13.317377  70.082575  110.709196  118.268178
# S_Degree     310.0   26.296694  37.559027 -11.058179    1.603727   11.767934
#
#                     75%         max
# P_incidence   72.877696  129.834041
# P_tilt        22.120395   49.431864
# L_angle       63.000000  125.742385
# S_slope       52.695888  121.429566
# P_radius     125.467674  163.071041
# S_Degree      41.287352  418.543082

# %% [markdown]
# #### 1.3

# %% [markdown]
# ##### a - Visualize a heatmap to understand correlation between all features

# %%
plt.figure(figsize = (15,7))
sns.heatmap(data = new_data.corr(),
            annot= True,cbar = True,cmap = 'icefire');
plt.style.use('default')

# %% [markdown]
# ##### b - Share insights on correlation

# %% [markdown]
# #### Positive Correlations :
# * [P_tilt]Pelvic tilt and incidence[P_incidence] have a significant positive correlation. This shows that the tilt angle tends to grow along with the pelvic incidence angle.
# * The relationship between L_angle(lumber lordosis) and P_tilt is favourable. This shows that the angle of lumbar lordosis tends to grow as the pelvic tilt angle increases.
# * There is a positive correlation between pelvic incidence and lumbar lordosis angle. This implies that as the incidence angle of the pelvis increases, the angle of lumbar lordosis also tends to increase.
# * Pelvic radius(p_radius) and sacral slope(S_slope) degree are positively correlated. This shows that the sacral slope degree tends to rise along with the pelvic radius.

# %% [markdown]
# ### Negative Correlations:
# * There is a negative correlation between pelvic tilt and sacral slope degree. This suggests that as the tilt angle of the pelvis increases, the sacral slope degree tends to decrease.
# * The relationship between sacral slope and pelvic incidence is unfavourable. This suggests that the sacral slope tends to decrease as the pelvic incidence angle rises.
# * There is a negative correlation between lumbar lordosis angle and sacral slope degree. This indicates that as the angle of lumbar lordosis increases, the sacral slope degree tends to decrease.
# * Sacral slope and lumbar lordosis angle are negatively correlated. This suggests that the sacral slope tends to decrease as the angle of lumbar lordosis increases.

# %% [markdown]
# ##### c - Visualize a pairplot with 3 classes distinguished by colors and share insights

# %%
sns.pairplot(data = new_data,hue = 'Class',palette = 'dark',corner = True);
plt.style.use('default')

# %% [markdown]
# ### Insights :
# * P_incidence: It can be comprehended that the range and spread of pelvic incidence(p_incidence) values in the dataset by looking at the distribution.
# * P_tilt: The pelvic tilt distribution and its relationships to other factors are shown in the pairplot. This can reveal any patterns or relationships between pelvic tilt and other characteristics.
# * S_slope: This attribute calculates the angle between the horizontal and the sacral plate.The properties and probable patterns connected with sacral slope by analysing its distribution and relationships with other variables in the pairplot.
# * Class: The class label or the target variable is represented by this attribute. The different classes can be visually identified by utilising the [hue] option in the pairplot. This helps us to investigate how the other qualities differ in relation to the class labels, identifying any class separation, correlations, or overlapping patterns.

# %% [markdown]
# ##### d - Visualize a jointplot for ‘P_incidence’ and ‘S_slope’ and share insights

# %%
sns.jointplot(data = new_data,x = 'P_incidence',y = 'S_slope',kind = 'reg');
plt.style.use('default')

# %% [markdown]
# ### Insights
# * Along with the scatter plot, the jointplot displays a histogram for each variable ('P_incidence' and 'S_slope'). This enables us to identify any trends, clusters, or data gaps by looking at the distribution of each variable separately.
# * The regression line displays the data's overall trend. The direction of the association between "P_incidence" and "S_slope" can be seen by looking at the regression line. Positive correlation is indicated by a line that slopes upward from left to right; this means that as 'P_incidence' rises, 'S_slope' also tends to rise.
# * Any probable outliers in the data are also highlighted by the jointplot.The points that fall far from the regression line can be used to represent them. Any odd or exceptional cases in the relationship between "P_incidence" and "S_slope" can be better understood by identifying outliers.

# %% [markdown]
# ##### e - Visualize a boxplot to check distribution of the features and share insights.

# %%
plt.figure(figsize = (8,5));
sns.boxplot(data = new_data,palette = 'Accent');
plt.title('Boxplot',color = 'dodgerblue',size = 30)
plt.tick_params(axis='x', labelsize= 10, colors='brown')
plt.tick_params(axis='y', labelsize= 10, colors='brown')
plt.grid(ls = 'dotted',c = 'dimgray',lw = 2)

# %% [markdown]
# ### Insights
# * P_incidence: The pelvic incidence value distribution reveals a generally narrow range with a few outliers on the high end. The median number reveals the data's centre tendency.
# * P_tilt : When compared to pelvic incidence, the boxplot for pelvic tilt shows a greater range of values. On both extremities of the distribution, there are a few outliers that point to some extreme numbers. An estimation of the central tendency is given by the median value.
# * L_angle: The boxplot for lumbar lordosis angle shows a relatively narrow range of values. The distribution appears slightly skewed towards higher values. There are a few outliers on the lower end, indicating some uncommon observations.
# * S_slope: There are no obvious outliers in the boxplot for sacral slope, which shows a modest range of values. The distribution is generally symmetrical, and the median value represents the central tendency.
# * P_radius: The boxplot for pelvic radius shows a narrow range of values, with a few outliers on the lower end. The median value provides an estimate of the central tendency. The distribution appears slightly skewed towards higher values.
# * S_Degree: A wide range of values are shown in the boxplot for the s_degree, with some extreme outliers on the higher end. The distribution looks to be positively skewed, and the median value represents the central tendency.

# %% [markdown]
# ### 1.4

# %% [markdown]
# ##### a - Split data into X and Y.

# %%
new_data
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius    S_Degree  \
# 0      38.505273  16.964297  35.112814  21.540976  127.632875    7.986683
# 1      54.920858  18.968430  51.601455  35.952428  125.846646    2.001642
# 2      44.362490   8.945435  46.902096  35.417055  129.220682    4.994195
# 3      48.318931  17.452121  48.000000  30.866809  128.980308   -0.910941
# 4      45.701789  10.659859  42.577846  35.041929  130.178314   -3.388910
# ..           ...        ...        ...        ...         ...         ...
# 305    80.111572  33.942432  85.101608  46.169139  125.593624  100.292107
# 306    95.480229  46.550053  59.000000  48.930176   96.683903   77.283072
# 307    74.094731  18.823727  76.032156  55.271004  128.405731   73.388216
# 308    87.679087  20.365613  93.822416  67.313473  120.944829   76.730629
# 309    48.259920  16.417462  36.329137  31.842457   94.882336   28.343799
#
#       Class
# 0    Normal
# 1    Normal
# 2    Normal
# 3    Normal
# ...

# %%
x = new_data.iloc[: ,: 6]
y = new_data['Class']

# %% [markdown]
# ##### Scaling the data

# %%
from sklearn.preprocessing import RobustScaler

x_new = RobustScaler().fit_transform(x)

# %% [markdown]
# ##### b - Split data into train and test with 80:20 proportion

# %%
x_train_new,x_test_new,y_train,y_test = train_test_split(x_new,y,test_size = 0.2,random_state = 42)

# %% [markdown]
# ##### c - Train a Supervised Learning Classification base model using KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors = 99,weights = 'distance')
knn_model.fit(x_train_new,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=99, weights='distance')

# %%
y_pred1 = knn_model.predict(x_test_new)

# %% [markdown]
# ##### d - Print all the possible performance metrics for both train and test data

# %%
from sklearn.metrics import average_precision_score, confusion_matrix, accuracy_score, classification_report, plot_confusion_matrix

# %% [markdown]
# ###### 1 : Scores of training and Testing Data

# %%
print('Score for Training Data : ',knn_model.score(x_train_new,y_train))
print(' ')
print('Score for Testing Data : ',round(knn_model.score(x_test_new,y_test),2))
# Out:
# Score for Training Data :  1.0
#
# Score for Testing Data :  0.77

# %% [markdown]
# Training Data ha fit the data very well when compared to test data

# %% [markdown]
# ###### 2 :  Accuracy

# %%
print(accuracy_score(y_test,y_pred1))
# Out:
# 0.7741935483870968

# %%
def rightly_identified(actual, predictions):
    a = pd.DataFrame()
    for i in np.sort(actual.unique()):
        try:
            a.loc[i,'total_instances'] = len(actual[actual == i])
            a.loc[i, 'identified_right'] = pd.Series(predictions[actual == i]).value_counts()[i]
            a.loc[i, '%'] = round(100*pd.Series(predictions[actual == i]).value_counts()[i]/len(actual[actual == i]), 1)
        except:
            a.loc[i, '%'] = 0.0
    return a

# %%
pred_vs_actual_model_initial = rightly_identified(y_test, y_pred1)

# %%
pred_vs_actual_model_initial
# Out:
#         total_instances  identified_right     %
# Normal             22.0              19.0  86.4
# Type_H             10.0               3.0  30.0
# Type_S             30.0              26.0  86.7

# %% [markdown]
# ###### 3 : Precison /  Sensitivity / F1_Score / Suppot

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.63      0.86      0.73        22
#       Type_H       0.60      0.30      0.40        10
#       Type_S       0.96      0.87      0.91        30
#
#     accuracy                           0.77        62
#    macro avg       0.73      0.68      0.68        62
# weighted avg       0.79      0.77      0.77        62

# %% [markdown]
# ###### 4 : Confusion Matrix

# %%
plot_confusion_matrix(knn_model,
                     x_test_new,
                     y_test,
                     values_format =  'd',
                     display_labels = ['Normal','Type H','Tpye S']);
# Out:
# C:\Users\SAIF MERCHANT\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### 1.5

# %% [markdown]
# ##### a - Experiment with various parameters to improve performance of the base model

# %%
myList = list(range(1,100))
scores =[]
for k in myList:
    knn_model = KNeighborsClassifier(n_neighbors = k, weights = 'distance' )
    knn_model.fit(x_train_new, y_train)
    scores.append(knn_model.score(x_test_new, y_test))
print(f"Scores : {scores}")
print(' ')
print(' ')
MSE = [1 - x for x in scores] 
optimal_k = myList[MSE.index(min(MSE))]
print("The optimal number for k is %d" % optimal_k)
# Out:
# Scores : [0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8548387096774194, 0.8548387096774194, 0.8548387096774194, 0.8387096774193549, 0.8548387096774194, 0.8387096774193549, 0.8387096774193549, 0.8548387096774194, 0.8709677419354839, 0.8709677419354839, 0.8709677419354839, 0.8709677419354839, 0.8548387096774194, 0.8225806451612904, 0.8225806451612904, 0.8225806451612904, 0.8064516129032258, 0.8064516129032258, 0.8225806451612904, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8548387096774194, 0.8387096774193549, 0.8225806451612904, 0.8225806451612904, 0.8225806451612904, 0.8225806451612904, 0.8225806451612904, 0.8225806451612904, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8387096774193549, 0.8225806451612904, 0.8387096774193549, 0.838709
# ...

# %% [markdown]
# Plotting misclassification error vs k (with k value on X-axis) using matplotlib.

# %%
plt.plot(myList,scores,'o-');

# %% [markdown]
# ##### b - Clearly showcase improvement in performance achieved

# %%
from sklearn.neighbors import KNeighborsClassifier
final_knn_model = KNeighborsClassifier(n_neighbors = 12,weights = 'distance')
final_knn_model.fit(x_train_new,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12, weights='distance')

# %%
y_pred2 = final_knn_model.predict(x_test_new)

# %%
pred_vs_actual_model_final = rightly_identified(y_test, y_pred2)

# %%
pred_vs_actual_model_final
# Out:
#         total_instances  identified_right     %
# Normal             22.0              19.0  86.4
# Type_H             10.0               8.0  80.0
# Type_S             30.0              27.0  90.0

# %%
print('Score for Training Data : ',final_knn_model.score(x_train_new,y_train))
print(' ')
print('Score for Testing Data : ',round(final_knn_model.score(x_test_new,y_test),2))
# Out:
# Score for Training Data :  1.0
#
# Score for Testing Data :  0.87

# %%
print(accuracy_score(y_test,y_pred2))
# Out:
# 0.8709677419354839

# %%
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.79      0.86      0.83        22
#       Type_H       0.80      0.80      0.80        10
#       Type_S       0.96      0.90      0.93        30
#
#     accuracy                           0.87        62
#    macro avg       0.85      0.85      0.85        62
# weighted avg       0.88      0.87      0.87        62

# %%
plot_confusion_matrix(final_knn_model,
                     x_test_new,
                     y_test,
                     values_format =  'd',
                     display_labels = ['Normal','Type H','Tpye S']);
# Out:
# C:\Users\SAIF MERCHANT\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# #### Model Comparison

# %%
result = {}

result['Initial kNN Model'] = pred_vs_actual_model_initial.drop(columns= 'total_instances')
result['Final kNN Model'] = pred_vs_actual_model_final.drop(columns= 'total_instances')

# %%
pd.concat(result, axis = 1)
# Out:
#        Initial kNN Model        Final kNN Model
#         identified_right     % identified_right     %
# Normal              19.0  86.4             19.0  86.4
# Type_H               3.0  30.0              8.0  80.0
# Type_S              26.0  86.7             27.0  90.0

# %% [markdown]
# ##### c - Clearly state which parameters contributed most to improve model performance

# %% [markdown]
# INITIAL MODEL
# ![image-6.png](attachment:image-6.png)
#  ### vs
# FINAL MODEL
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Observations
# * Clearly, the value of k plays a prominent role in the model performance and the respective predictions associated from it.
# * The Initial model (k = 99) and the Final model(k = 12) performed equally well for the Normal Class.
# * The Initial model fared far worse for Type_H when compared to Final model ie the Final model managed to improve by 50%.
# * Even the performance of Type_S data was enhanced in the Final model by 3.3%.
# * It is a remarkable achievement because even the model's performance for the Test data was improved by 10%.

# %% [markdown]
# # Part 2

# %% [markdown]
# ### 2.1

# %% [markdown]
# ##### a - Read both the Datasets ‘Data1’ and ‘Data 2’ as DataFrame and store them into two separate variables

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import average_precision_score, confusion_matrix, accuracy_score, classification_report, plot_confusion_matrix
from sklearn.model_selection import GridSearchCV  
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import scale
from sklearn.utils import resample

# %%
data1 = pd.read_csv("C:/Users/SAIF MERCHANT/Desktop/Great Learning/Supervised Learning/Project/Part2+-+Data1.csv")
data2 = pd.read_csv("C:/Users/SAIF MERCHANT/Desktop/Great Learning/Supervised Learning/Project/Part2+-Data2.csv")

# %% [markdown]
# ##### b - Print shape and Column Names and DataTypes of both the Dataframes.

# %%
print('*****Shapes*****')
print(' ')
print(' ')
print('DataFrame 1 : ')
print(data1.shape)
print(' ')
print(' ')
print('DataFrame 2 : ')
print(data2.shape)
print(' ')
print('****************************************************************')
print(' ')
print('*****DataTypes*****')
print(' ')
print(' ')
print('DataFrame : ')
print(data1.dtypes)
print(' ')
print(' ')
print('Dataframe 2 : ')
print(data2.dtypes)
print(' ')
print('******************************************************************')
print(' ')
print('*****Column Names*****')
print(' ')
print(' ')
print('DataFrame 1 : ')
print(data1.columns)
print(' ')
print(' ')
print('DataFrame 2 : ')
print(data2.columns)
# Out:
# *****Shapes*****
#
#
# DataFrame 1 :
# (5000, 8)
#
#
# DataFrame 2 :
# (5000, 7)
#
# ****************************************************************
#
# *****DataTypes*****
#
#
# DataFrame :
# ID                       int64
# Age                      int64
# CustomerSince            int64
# HighestSpend             int64
# ZipCode                  int64
# HiddenScore              int64
# MonthlyAverageSpend    float64
# Level                    int64
# dtype: object
#
#
# Dataframe 2 :
# ID                       int64
# Mortgage                 int64
# Security                 int64
# FixedDepositAccount      int64
# InternetBanking          int64
# CreditCard               int64
# LoanOnCard             float64
# dtype: object
#
# ******************************************************************
#
# *****Column Names*****
#
#
# DataFrame 1 :
# Index(['ID', 'Age', 'CustomerSince', 'HighestSpend', 'ZipCode', 'HiddenScore',
#        'MonthlyAverageSpend', 'Level'],
# ...

# %% [markdown]
# ##### c - Merge both the Dataframes on ‘ID’ feature to form a single DataFrame

# %%
new_data2 = pd.merge(data1,data2,how = 'outer',on = 'ID')

# %%
new_data2
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode  HiddenScore  \
# 0        1   25              1            49    91107            4
# 1        2   45             19            34    90089            3
# 2        3   39             15            11    94720            1
# 3        4   35              9           100    94112            1
# 4        5   35              8            45    91330            4
# ...    ...  ...            ...           ...      ...          ...
# 4995  4996   29              3            40    92697            1
# 4996  4997   30              4            15    92037            4
# 4997  4998   63             39            24    93023            2
# 4998  4999   65             40            49    90034            3
# 4999  5000   28              4            83    92612            3
#
#       MonthlyAverageSpend  Level  Mortgage  Security  FixedDepositAccount  \
# 0                     1.6      1         0         1                    0
# ...

# %% [markdown]
# ##### d - Change Datatype of below features to ‘Object’
# ![image.png](attachment:image.png)

# %%
new_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Age                  5000 non-null   int64
#  2   CustomerSince        5000 non-null   int64
#  3   HighestSpend         5000 non-null   int64
#  4   ZipCode              5000 non-null   int64
#  5   HiddenScore          5000 non-null   int64
#  6   MonthlyAverageSpend  5000 non-null   float64
#  7   Level                5000 non-null   int64
#  8   Mortgage             5000 non-null   int64
#  9   Security             5000 non-null   int64
#  10  FixedDepositAccount  5000 non-null   int64
#  11  InternetBanking      5000 non-null   int64
#  12  CreditCard           5000 non-null   int64
#  13  LoanOnCard           4980 non-null   float64
# dtypes: float64(2), int64(12)
# memory usage: 585.9 KB

# %%
new_data2['CreditCard'] = new_data2['CreditCard'].astype('object')
new_data2['InternetBanking'] = new_data2['InternetBanking'].astype('object')
new_data2['FixedDepositAccount'] = new_data2['FixedDepositAccount'].astype('object')
new_data2['Security'] = new_data2['CreditCard'].astype('object')
new_data2['Level'] = new_data2['Level'].astype('object')
new_data2['HiddenScore'] = new_data2['HiddenScore'].astype('object')

# %%
new_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Age                  5000 non-null   int64
#  2   CustomerSince        5000 non-null   int64
#  3   HighestSpend         5000 non-null   int64
#  4   ZipCode              5000 non-null   int64
#  5   HiddenScore          5000 non-null   object
#  6   MonthlyAverageSpend  5000 non-null   float64
#  7   Level                5000 non-null   object
#  8   Mortgage             5000 non-null   int64
#  9   Security             5000 non-null   object
#  10  FixedDepositAccount  5000 non-null   object
#  11  InternetBanking      5000 non-null   object
#  12  CreditCard           5000 non-null   object
#  13  LoanOnCard           4980 non-null   float64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 585.9+ KB

# %% [markdown]
# ### 2.2

# %% [markdown]
# ##### a - Visualize distribution of Target variable ‘LoanOnCard’ and clearly share insights

# %%
new_data2['LoanOnCard'].value_counts()
# Out:
# 0.0    4500
# 1.0     480
# Name: LoanOnCard, dtype: int64

# %%
plt.figure(figsize = (15,8));
ax = sns.countplot(data = new_data2,x = 'LoanOnCard',palette = 'Set2');
plt.title('Distribution of Target variable',color = 'hotpink',size = 30)
plt.xlabel('LoanOnCard',color = 'tan',size = 20)
plt.ylabel('COUNT',color = 'tan',size = 20)
plt.tick_params(axis='x', labelsize=10, colors='salmon')
plt.tick_params(axis='y', labelsize=10, colors='salmon')
plt.grid(ls = 'dotted',lw = 1,color = 'brown')
for p in ax.patches: 
    ax.annotate(str((np.round(p.get_height()/len(new_data2)*100,decimals=0)))+'%', 
                (p.get_x()+p.get_width()/2., p.get_height()), ha='center', 
                va='center', xytext=(0, 10), textcoords='offset points')
plt.style.use('default')

# %% [markdown]
# ##### The target variable has two categories: 0 (no loan on card) and 1 (loan on card).
#     * The majority of the observations in the dataset have no loan on card (category 0), with a count of 4,500 (90.0%).
#     * The remaining 480 observations (10.0%) have a loan on card (category 1).
# ###### This demonstrates the dataset's imbalance since the vast majority of observations had no outstanding credit card debt. The effectiveness of machine learning models that were trained on this dataset may be impacted by this imbalance.
#
# ### Insights that can be gained from the bar plot
#     *A minor percentage of observers had a loan on their credit card.
#     *The dataset is unbalanced since most observations have no outstanding credit card debt.
#     *The target variable's distribution is skewed, with a long tail on the side of no card loan.

# %% [markdown]
# ##### b - Check the percentage of missing values and impute if required

# %%
new_data2.isnull().sum()
# Out:
# ID                      0
# Age                     0
# CustomerSince           0
# HighestSpend            0
# ZipCode                 0
# HiddenScore             0
# MonthlyAverageSpend     0
# Level                   0
# Mortgage                0
# Security                0
# FixedDepositAccount     0
# InternetBanking         0
# CreditCard              0
# LoanOnCard             20
# dtype: int64

# %%
pd.DataFrame({'Count' : new_data2.isnull().sum()[new_data2.isnull().sum() > 0],
             'Percentage' : (new_data2.isnull().sum()[new_data2.isnull().sum() > 0]/new_data2.shape[0])*100})
# Out:
#             Count  Percentage
# LoanOnCard     20         0.4

# %%
new_data2.loc[new_data2['LoanOnCard'].isnull() == True]
# Out:
#     ID  Age  CustomerSince  HighestSpend  ZipCode HiddenScore  \
# 0    1   25              1            49    91107           4
# 1    2   45             19            34    90089           3
# 2    3   39             15            11    94720           1
# 3    4   35              9           100    94112           1
# 4    5   35              8            45    91330           4
# 5    6   37             13            29    92121           4
# 6    7   53             27            72    91711           2
# 7    8   50             24            22    93943           1
# 8    9   35             10            81    90089           3
# 79  80   50             26            19    94720           2
# 80  81   60             36            41    95134           4
# 81  82   47             22            40    94612           3
# 82  83   41             16            82    92507           1
# 83  84   33              9            50    94305           1
# ...

# %%
rows_to_drop = [0,1,2,3,4,5,6,7,8,79,80,81,82,83,84,85,86,87,88,89] 
new_data2 = new_data2.drop(rows_to_drop).reset_index(drop = True)

# %%
new_data2
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode HiddenScore  \
# 0       10   34              9           180    93023           1
# 1       11   65             39           105    94710           4
# 2       12   29              5            45    90277           3
# 3       13   48             23           114    93106           2
# 4       14   59             32            40    94920           4
# ...    ...  ...            ...           ...      ...         ...
# 4975  4996   29              3            40    92697           1
# 4976  4997   30              4            15    92037           4
# 4977  4998   63             39            24    93023           2
# 4978  4999   65             40            49    90034           3
# 4979  5000   28              4            83    92612           3
#
#       MonthlyAverageSpend Level  Mortgage Security FixedDepositAccount  \
# 0                     8.9     3         0        0                   0
# ...

# %%
pd.DataFrame({'Count' : new_data2.isnull().sum()[new_data2.isnull().sum() > 0],
             'Percentage' : (new_data2.isnull().sum()[new_data2.isnull().sum() > 0]/new_data2.shape[0])*100})
# Out:
# Empty DataFrame
# Columns: [Count, Percentage]
# Index: []

# %%
new_data2.loc[new_data2['LoanOnCard'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [ID, Age, CustomerSince, HighestSpend, ZipCode, HiddenScore, MonthlyAverageSpend, Level, Mortgage, Security, FixedDepositAccount, InternetBanking, CreditCard, LoanOnCard]
# Index: []

# %% [markdown]
# ##### c - Check for unexpected values in each categorical variable and impute with best suitable value.

# %%
new_data2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Since there are no unexpected values in the entire data, lets proceed ahead

# %% [markdown]
# ### 2.3

# %% [markdown]
# ##### a- Split data into X and Y

# %%
x = new_data2.drop('LoanOnCard',axis = 1)
y = new_data2['LoanOnCard']

# %% [markdown]
# ##### b - Split data into train and test. Keep 25% data reserved for testing

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)

# %% [markdown]
# ##### c - Train a Supervised Learning Classification base model - Logistic Regression

# %%
log_model = LogisticRegression()
log_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ##### d - Print evaluation metrics for the model and clearly share insights

# %%
y_pred_logistic = log_model.predict(x_test)

# %% [markdown]
# ###### 1 : Scores of training and Testing Data

# %%
print('Score for Training Data : ',round(log_model.score(x_train,y_train),3))
print(' ')
print('Score for Testing Data : ',round(log_model.score(x_test,y_test),3))
# Out:
# Score for Training Data :  0.909
#
# Score for Testing Data :  0.904

# %% [markdown]
# Training Data ha fit the data very well when compared to test data

# %% [markdown]
# ###### 2 :  Accuracy

# %%
print(accuracy_score(y_test,y_pred_logistic))
# Out:
# 0.9044176706827309

# %%
def rightly_identified(actual, predictions):
    a = pd.DataFrame()
    for i in np.sort(actual.unique()):
        try:
            a.loc[i,'total_instances'] = len(actual[actual == i])
            a.loc[i, 'identified_right'] = pd.Series(predictions[actual == i]).value_counts()[i]
            a.loc[i, '%'] = round(100*pd.Series(predictions[actual == i]).value_counts()[i]/len(actual[actual == i]), 1)
        except:
            a.loc[i, '%'] = 0.0
    return a

# %%
pred_vs_actual_model_logistic_1 = rightly_identified(y_test, y_pred_logistic)

# %%
pred_vs_actual_model_logistic_1
# Out:
#      total_instances  identified_right     %
# 0.0           1128.0            1091.0  96.7
# 1.0            117.0              35.0  29.9

# %% [markdown]
# ###### 3 : Precison /  Sensitivity / F1_Score / Suppot

# %%
print(classification_report(y_test,y_pred_logistic))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95      1128
#          1.0       0.49      0.30      0.37       117
#
#     accuracy                           0.90      1245
#    macro avg       0.71      0.63      0.66      1245
# weighted avg       0.89      0.90      0.89      1245

# %% [markdown]
# ###### 4 : Confusion Matrix

# %%
def con_matrix(actual, predictions):
    from sklearn.metrics import confusion_matrix
    matrix = pd.DataFrame(confusion_matrix(actual, predictions), columns = np.unique(actual), index = np.unique(actual))
    matrix.loc[:,'total_count_actual_class'] = matrix.sum(axis = 1)
    matrix.loc['total_count_predicted'] = matrix.sum(axis = 0)
    return matrix

con_matrix(y_test, y_pred_logistic)
# Out:
#                         0.0  1.0  total_count_actual_class
# 0.0                    1091   37                      1128
# 1.0                      82   35                       117
# total_count_predicted  1173   72                      1245

# %% [markdown]
# ### Insights
# * It appears that roughly 90% of the training and test sets were fitted similarly.
# * Surprisingly, on one side a large percentage of 0s were accurately identified (90%) but only 30% of 1s were successfully identified.
# * The classification report also notes that the precision, f1-score, and sensitivity were significantly higher for 0s than for 1s.
# * With that the confusion matrix tells us that there are 1091 True positives,35 True negatives,82 False negatives and 37 False positives.

# %% [markdown]
# ##### e - Balance the data using the right balancing technique.

# %%
len(new_data2)
# Out:
# 4980

# %%
new_data2['LoanOnCard'].value_counts()
# Out:
# 0.0    4500
# 1.0     480
# Name: LoanOnCard, dtype: int64

# %% [markdown]
# The no of 0s are 4500, lets upsample the 1s to 4500

# %%
loan_0 = new_data2[new_data2['LoanOnCard'] == 0]
loan_1 = new_data2[new_data2['LoanOnCard'] == 1]

# %%
loan_1_downsampled = resample(loan_1,
                            replace = True,
                            n_samples = 4500,
                            random_state = 42)
len(loan_1_downsampled)
# Out:
# 4500

# %%
new_data2_downsample = pd.concat([loan_0,loan_1_downsampled])

# %%
new_data2_downsample
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode HiddenScore  \
# 1       11   65             39           105    94710           4
# 2       12   29              5            45    90277           3
# 3       13   48             23           114    93106           2
# 4       14   59             32            40    94920           4
# 5       15   67             41           112    91741           1
# ...    ...  ...            ...           ...      ...         ...
# 3631  3652   49             23           140    90504           1
# 2836  2857   36             10           172    94704           4
# 661    682   34              9           164    94720           1
# 3140  3161   41             15           158    94304           1
# 3928  3949   37             12           123    94304           4
#
#       MonthlyAverageSpend Level  Mortgage Security FixedDepositAccount  \
# 1                     2.4     3         0        0                   0
# ...

# %%
x1 = new_data2_downsample.drop('LoanOnCard',axis = 1)
y1 = new_data2_downsample['LoanOnCard']

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size = 0.25,random_state = 42)
x_train_scaled = scale(x_train)
x_test_scaled = scale(x_test)

# %% [markdown]
# ##### f- Again train the same previous model on balanced data

# %%
log_model_downsampled = LogisticRegression()
log_model_downsampled.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ##### g - Print evaluation metrics for the model and clearly share insights

# %%
y_pred_logistic_2 = log_model_downsampled.predict(x_test)

# %% [markdown]
# ###### 1 : Scores of training and Testing Data

# %%
print('Score for Training Data : ',round(log_model_downsampled.score(x_train,y_train),3))
print(' ')
print('Score for Testing Data : ',round(log_model_downsampled.score(x_test,y_test),3))
# Out:
# Score for Training Data :  0.879
#
# Score for Testing Data :  0.867

# %% [markdown]
# Training Data ha fit the data very well when compared to test data

# %% [markdown]
# ###### 2 :  Accuracy

# %%
print(accuracy_score(y_test,y_pred_logistic_2))
# Out:
# 0.8666666666666667

# %%
def rightly_identified(actual, predictions):
    a = pd.DataFrame()
    for i in np.sort(actual.unique()):
        try:
            a.loc[i,'total_instances'] = len(actual[actual == i])
            a.loc[i, 'identified_right'] = pd.Series(predictions[actual == i]).value_counts()[i]
            a.loc[i, '%'] = round(100*pd.Series(predictions[actual == i]).value_counts()[i]/len(actual[actual == i]), 1)
        except:
            a.loc[i, '%'] = 0.0
    return a

# %%
pred_vs_actual_model_logistic_2 = rightly_identified(y_test, y_pred_logistic_2)

# %%
pred_vs_actual_model_logistic_2
# Out:
#      total_instances  identified_right     %
# 0.0           1118.0             965.0  86.3
# 1.0           1132.0             985.0  87.0

# %% [markdown]
# ###### 3 : Precison /  Sensitivity / F1_Score / Suppot

# %%
print(classification_report(y_test,y_pred_logistic_2))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.86      0.87      1118
#          1.0       0.87      0.87      0.87      1132
#
#     accuracy                           0.87      2250
#    macro avg       0.87      0.87      0.87      2250
# weighted avg       0.87      0.87      0.87      2250

# %% [markdown]
# ###### 4 : Confusion Matrix

# %%
def con_matrix(actual, predictions):
    from sklearn.metrics import confusion_matrix
    matrix = pd.DataFrame(confusion_matrix(actual, predictions), columns = np.unique(actual), index = np.unique(actual))
    matrix.loc[:,'total_count_actual_class'] = matrix.sum(axis = 1)
    matrix.loc['total_count_predicted'] = matrix.sum(axis = 0)
    return matrix

con_matrix(y_test, y_pred_logistic_2)
# Out:
#                         0.0   1.0  total_count_actual_class
# 0.0                     965   153                      1118
# 1.0                     147   985                      1132
# total_count_predicted  1112  1138                      2250

# %% [markdown]
# #### Comparing the initial Logistic Model and the downsampled Logistic model

# %%
result = {}

result['Initial Logistic Model'] = pred_vs_actual_model_logistic_1.drop(columns= 'total_instances')
result['Final Logistic Model'] = pred_vs_actual_model_logistic_2.drop(columns= 'total_instances')

# %%
pd.concat(result, axis = 1)
# Out:
#     Initial Logistic Model       Final Logistic Model
#           identified_right     %     identified_right     %
# 0.0                 1091.0  96.7                965.0  86.3
# 1.0                   35.0  29.9                985.0  87.0

# %% [markdown]
# ### Insights
# * The balanced/upsampled data has performed well than the initially built logistic model.
# * All the evaluation metrics such as accuracy,sensitivity and F1-score have improved for the new model.
# * Though for 0s, the correctly identified proportion decreased by 10.5%.
# * On the other hand, for 1s, the proportion that was properly identified sharply jumped by 57.1%.

# %% [markdown]
# ### 2.4

# %% [markdown]
# ##### a- Train a base model each for SVM, KNN

# %% [markdown]
# #### Base Model for kNN

# %%
knn_base_model = KNeighborsClassifier(n_neighbors = 22,weights = 'distance')
knn_base_model.fit(x_train_scaled,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=22, weights='distance')

# %%
y_pred_base_knn = knn_base_model.predict(x_test_scaled)

# %% [markdown]
# ###### 1 : Scores of training and Testing Data

# %%
print('Score for Training Data : ',round(knn_base_model.score(x_train_scaled,y_train),3))
print(' ')
print('Score for Testing Data : ',round(knn_base_model.score(x_test_scaled,y_test),3))
# Out:
# Score for Training Data :  1.0
#
# Score for Testing Data :  0.952

# %% [markdown]
# ###### 2 :  Accuracy

# %%
print(accuracy_score(y_test,y_pred_base_knn))
# Out:
# 0.9515555555555556

# %%
def rightly_identified(actual, predictions):
    a = pd.DataFrame()
    for i in np.sort(actual.unique()):
        try:
            a.loc[i,'total_instances'] = len(actual[actual == i])
            a.loc[i, 'identified_right'] = pd.Series(predictions[actual == i]).value_counts()[i]
            a.loc[i, '%'] = round(100*pd.Series(predictions[actual == i]).value_counts()[i]/len(actual[actual == i]), 1)
        except:
            a.loc[i, '%'] = 0.0
    return a

# %%
pred_vs_actual_base_knn = rightly_identified(y_test, y_pred_base_knn)

# %%
pred_vs_actual_base_knn
# Out:
#      total_instances  identified_right      %
# 0.0           1118.0            1009.0   90.3
# 1.0           1132.0            1132.0  100.0

# %% [markdown]
# ###### 3 : Precison /  Sensitivity / F1_Score / Suppot

# %%
print(classification_report(y_test,y_pred_base_knn))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.90      0.95      1118
#          1.0       0.91      1.00      0.95      1132
#
#     accuracy                           0.95      2250
#    macro avg       0.96      0.95      0.95      2250
# weighted avg       0.96      0.95      0.95      2250

# %% [markdown]
# ###### 4 : Confusion Matrix

# %%
def con_matrix(actual, predictions):
    from sklearn.metrics import confusion_matrix
    matrix = pd.DataFrame(confusion_matrix(actual, predictions), columns = np.unique(actual), index = np.unique(actual))
    matrix.loc[:,'total_count_actual_class'] = matrix.sum(axis = 1)
    matrix.loc['total_count_predicted'] = matrix.sum(axis = 0)
    return matrix

con_matrix(y_test, y_pred_base_knn)
# Out:
#                         0.0   1.0  total_count_actual_class
# 0.0                    1009   109                      1118
# 1.0                       0  1132                      1132
# total_count_predicted  1009  1241                      2250

# %% [markdown]
# #### Base Model for SVM

# %%
svm_base_model = SVC(random_state = 42)
svm_base_model.fit(x_train_scaled,y_train)
# Out:
# SVC(random_state=42)

# %%
y_pred_base_svm = svm_base_model.predict(x_test_scaled)

# %% [markdown]
# ###### 1 : Scores of training and Testing Data

# %%
print('Score for Training Data : ',round(svm_base_model.score(x_train_scaled,y_train),3))
print(' ')
print('Score for Testing Data : ',round(svm_base_model.score(x_test_scaled,y_test),3))
# Out:
# Score for Training Data :  0.975
#
# Score for Testing Data :  0.971

# %% [markdown]
# ###### 2 :  Accuracy

# %%
print(accuracy_score(y_test,y_pred_base_svm))
# Out:
# 0.9711111111111111

# %%
def rightly_identified(actual, predictions):
    a = pd.DataFrame()
    for i in np.sort(actual.unique()):
        try:
            a.loc[i,'total_instances'] = len(actual[actual == i])
            a.loc[i, 'identified_right'] = pd.Series(predictions[actual == i]).value_counts()[i]
            a.loc[i, '%'] = round(100*pd.Series(predictions[actual == i]).value_counts()[i]/len(actual[actual == i]), 1)
        except:
            a.loc[i, '%'] = 0.0
    return a

# %%
pred_vs_actual_base_svm = rightly_identified(y_test, y_pred_base_svm)

# %%
pred_vs_actual_base_svm
# Out:
#      total_instances  identified_right     %
# 0.0           1118.0            1080.0  96.6
# 1.0           1132.0            1105.0  97.6

# %% [markdown]
# ###### 3 : Precison /  Sensitivity / F1_Score / Suppot

# %%
print(classification_report(y_test,y_pred_base_svm))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.97      1118
#          1.0       0.97      0.98      0.97      1132
#
#     accuracy                           0.97      2250
#    macro avg       0.97      0.97      0.97      2250
# weighted avg       0.97      0.97      0.97      2250

# %% [markdown]
# ###### 4 : Confusion Matrix

# %%
def con_matrix(actual, predictions):
    from sklearn.metrics import confusion_matrix
    matrix = pd.DataFrame(confusion_matrix(actual, predictions), columns = np.unique(actual), index = np.unique(actual))
    matrix.loc[:,'total_count_actual_class'] = matrix.sum(axis = 1)
    matrix.loc['total_count_predicted'] = matrix.sum(axis = 0)
    return matrix

con_matrix(y_test, y_pred_base_svm)
# Out:
#                         0.0   1.0  total_count_actual_class
# 0.0                    1080    38                      1118
# 1.0                      27  1105                      1132
# total_count_predicted  1107  1143                      2250

# %% [markdown]
# ##### b - Tune parameters for each of the models wherever required and finalize a model

# %% [markdown]
# #### Tuning the best value for k

# %%
myList = list(range(1,100))
MSE = [1 - x for x in scores] #misclassification error
optimal_k = myList[MSE.index(min(MSE))]
print("The optimal number for k is %d" % optimal_k)
# Out:
# The optimal number for k is 12

# %% [markdown]
# #### Final Model for kNN

# %%
knn_final_model = KNeighborsClassifier(n_neighbors = 12,weights = 'distance')
knn_final_model.fit(x_train_scaled,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12, weights='distance')

# %% [markdown]
# #### Tuning the best value for C and gamma

# %%
parameter_grid = [
    {'C' : [0.5,1,10,100],
    'gamma' : ['scale',1,0.1,0.01,0.001],
    'kernel' : ['rbf']}
]
optimal_parameters = GridSearchCV(
    SVC(),
    parameter_grid,
    cv = 5,
    scoring = 'accuracy',
    verbose = 0, 
)
optimal_parameters.fit(x_train_scaled,y_train)
print(optimal_parameters.best_params_)
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'rbf'}

# %% [markdown]
# #### Note :
#
#     The size of n_samples is huge hence the processing time of the crossvalidation/Gridsearch might take some time( particularly between 30 secs - 1 min)

# %% [markdown]
# #### Final Model for SVM

# %%
svm_final_model = SVC(random_state = 42,C = 1,gamma = 1 )
svm_final_model.fit(x_train_scaled,y_train)
# Out:
# SVC(C=1, gamma=1, random_state=42)

# %% [markdown]
# ##### c- Print evaluation metrics for final mode

# %% [markdown]
# #### For Final kNN Model

# %%
y_pred_final_knn = knn_final_model.predict(x_test_scaled)

# %% [markdown]
# ###### 1 : Scores of training and Testing Data

# %%
print('Score for Training Data : ',round(knn_final_model.score(x_train_scaled,y_train),3))
print(' ')
print('Score for Testing Data : ',round(knn_final_model.score(x_test_scaled,y_test),3))
# Out:
# Score for Training Data :  1.0
#
# Score for Testing Data :  0.962

# %% [markdown]
# ###### 2 :  Accuracy

# %%
print(accuracy_score(y_test,y_pred_final_knn))
# Out:
# 0.9617777777777777

# %%
def rightly_identified(actual, predictions):
    a = pd.DataFrame()
    for i in np.sort(actual.unique()):
        try:
            a.loc[i,'total_instances'] = len(actual[actual == i])
            a.loc[i, 'identified_right'] = pd.Series(predictions[actual == i]).value_counts()[i]
            a.loc[i, '%'] = round(100*pd.Series(predictions[actual == i]).value_counts()[i]/len(actual[actual == i]), 1)
        except:
            a.loc[i, '%'] = 0.0
    return a

# %%
pred_vs_actual_final_knn = rightly_identified(y_test, y_pred_final_knn)

# %%
pred_vs_actual_final_knn
# Out:
#      total_instances  identified_right      %
# 0.0           1118.0            1032.0   92.3
# 1.0           1132.0            1132.0  100.0

# %% [markdown]
# ###### 3 : Precison /  Sensitivity / F1_Score / Suppot

# %%
print(classification_report(y_test,y_pred_final_knn))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.92      0.96      1118
#          1.0       0.93      1.00      0.96      1132
#
#     accuracy                           0.96      2250
#    macro avg       0.96      0.96      0.96      2250
# weighted avg       0.96      0.96      0.96      2250

# %% [markdown]
# ###### 4 : Confusion Matrix

# %%
def con_matrix(actual, predictions):
    from sklearn.metrics import confusion_matrix
    matrix = pd.DataFrame(confusion_matrix(actual, predictions), columns = np.unique(actual), index = np.unique(actual))
    matrix.loc[:,'total_count_actual_class'] = matrix.sum(axis = 1)
    matrix.loc['total_count_predicted'] = matrix.sum(axis = 0)
    return matrix

con_matrix(y_test, y_pred_final_knn)
# Out:
#                         0.0   1.0  total_count_actual_class
# 0.0                    1032    86                      1118
# 1.0                       0  1132                      1132
# total_count_predicted  1032  1218                      2250

# %% [markdown]
# #### For Final SVM Model

# %%
y_pred_final_svm = svm_final_model.predict(x_test_scaled)

# %% [markdown]
# ###### 1 : Scores of training and Testing Data

# %%
print('Score for Training Data : ',round(svm_final_model.score(x_train_scaled,y_train),3))
print(' ')
print('Score for Testing Data : ',round(svm_final_model.score(x_test_scaled,y_test),3))
# Out:
# Score for Training Data :  1.0
#
# Score for Testing Data :  0.999

# %% [markdown]
# ###### 2 :  Accuracy

# %%
print(accuracy_score(y_test,y_pred_final_svm))
# Out:
# 0.9991111111111111

# %%
def rightly_identified(actual, predictions):
    a = pd.DataFrame()
    for i in np.sort(actual.unique()):
        try:
            a.loc[i,'total_instances'] = len(actual[actual == i])
            a.loc[i, 'identified_right'] = pd.Series(predictions[actual == i]).value_counts()[i]
            a.loc[i, '%'] = round(100*pd.Series(predictions[actual == i]).value_counts()[i]/len(actual[actual == i]), 1)
        except:
            a.loc[i, '%'] = 0.0
    return a

# %%
pred_vs_actual_final_svm = rightly_identified(y_test, y_pred_final_svm)

# %%
pred_vs_actual_final_svm
# Out:
#      total_instances  identified_right      %
# 0.0           1118.0            1116.0   99.8
# 1.0           1132.0            1132.0  100.0

# %% [markdown]
# ###### 3 : Precison /  Sensitivity / F1_Score / Suppot

# %%
print(classification_report(y_test,y_pred_final_svm))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1118
#          1.0       1.00      1.00      1.00      1132
#
#     accuracy                           1.00      2250
#    macro avg       1.00      1.00      1.00      2250
# weighted avg       1.00      1.00      1.00      2250

# %% [markdown]
# ###### 4 : Confusion Matrix

# %%
def con_matrix(actual, predictions):
    from sklearn.metrics import confusion_matrix
    matrix = pd.DataFrame(confusion_matrix(actual, predictions), columns = np.unique(actual), index = np.unique(actual))
    matrix.loc[:,'total_count_actual_class'] = matrix.sum(axis = 1)
    matrix.loc['total_count_predicted'] = matrix.sum(axis = 0)
    return matrix

con_matrix(y_test, y_pred_final_svm)
# Out:
#                         0.0   1.0  total_count_actual_class
# 0.0                    1116     2                      1118
# 1.0                       0  1132                      1132
# total_count_predicted  1116  1134                      2250

# %% [markdown]
# ##### d :  Share improvement achieved from base model to final model

# %%
result = {}

result['Base SVM Model'] = pred_vs_actual_base_svm.drop(columns= 'total_instances')
result['Final SVM Model'] = pred_vs_actual_final_svm.drop(columns= 'total_instances')

# %%
pd.concat(result, axis = 1)
# Out:
#       Base SVM Model        Final SVM Model
#     identified_right     % identified_right      %
# 0.0           1080.0  96.6           1116.0   99.8
# 1.0           1105.0  97.6           1132.0  100.0

# %%
result = {}

result['Base kNN Model'] = pred_vs_actual_base_knn.drop(columns= 'total_instances')
result['Final kNN Model'] = pred_vs_actual_final_knn.drop(columns= 'total_instances')

# %%
pd.concat(result, axis = 1)
# Out:
#       Base kNN Model         Final kNN Model
#     identified_right      % identified_right      %
# 0.0           1009.0   90.3           1032.0   92.3
# 1.0           1132.0  100.0           1132.0  100.0

# %% [markdown]
# ### Insights
# * It appears that both, the Final kNN model and the Final SVM model have performed incredibly well in comparison to their respective Base Models.
# * Performance of 0s and 1s for SVM models improved by 3.3% 2.4% respectively from base to final model.
# * In kNN models, both the base and final models' 1s have demonstrated excellent performance
# and the 0s have shown improvement for final model by 2%.
# * In summary,the final SVM and kNN models performed remarkably well, with the SVM model exhibiting improved accuracy for instances labelled as 1 and 0, and the kNN model showing improvement in predicting instances labelled as 1 and 0.
